-- %%
GRANT SELECT ON TABLE catalog_dev.bronze.ventas TO `clasesx@smartdatagr7outlook.onmicrosoft.com`;

-- %%
GRANT USE CATALOG ON CATALOG catalog_dev TO `Analistas`;

-- %%
GRANT USE SCHEMA ON SCHEMA catalog_dev.bronze TO `Desarrolladores`;
GRANT CREATE ON SCHEMA catalog_dev.bronze TO `Desarrolladores`;

-- %%
GRANT SELECT ON TABLE catalog_dev.bronze.productos TO `Admins_Smart`;
GRANT SELECT ON TABLE catalog_dev.silver.clientes_validos TO `Analistas`;

-- %%
SHOW GRANTS ON TABLE catalog_dev.bronze.productos;

-- %%
SHOW GRANTS ON SCHEMA catalog_dev.bronze;

-- %%
SHOW GRANTS ON CATALOG catalog_dev;

-- %%
REVOKE USE SCHEMA ON SCHEMA catalog_dev.bronze FROM `clasesx@smartdatagr7outlook.onmicrosoft.com`;

-- %%
SHOW GRANTS ON SCHEMA catalog_dev.bronze;
